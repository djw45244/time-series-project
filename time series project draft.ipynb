# %% [markdown]
# ![Final795_1.png](attachment:Final795_1.png)

# %% [markdown]
# <p style="text-align:left;font-size:16px;font-family:Helvetica,sans-serif;font-style:italic">
# Author: Devan Walton
# <span style="float:right;">
# Date: 12/8/2021</span>
# </p>
#
# ***
#
# <h3 style="font-size:35px;font-family:Helvetica,sans-serif;font-weight:bold">
# 0.0 - Pre-lab</h3>
#
# ***

# %% [markdown]
# ![Sample1-01.png](attachment:Sample1-01.png)

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 0.1 - Accessing New Harmony, IN Data </h4>

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 0.2 - Accessing Cannelton, IN Data </h4>

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 0.3 - Accessing Hermann, MO Data </h4>

# %% [markdown]
# <h3 style="font-size:35px;font-family:Helvetica,sans-serif;font-weight:bold">
# 1.0 - Initial Load and Setup</h3>
#
# ***

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 1.1 - Loading libraries </h4>

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 1.2 - Setting Variables </h4>

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 1.3 - Reading Files into Dataframes  </h4>

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 1.4 - Cleaning and Filling Data </h4>

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 1.5 - Initial Unit Conversions </h4>

# %% [markdown]
# <h3 style="font-size:35px;font-family:Helvetica,sans-serif;font-weight:bold">
# 2.0 - Discharge Comparison</h3>
#
# ***

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 2.1 - Combine Discharge Data from each Site into the Q Dataframe  </h4>

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 2.2 - Resample Data from Daily to 20-day  </h4>

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 2.3 - Trim Data to a Shared Period of Record  </h4>

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 2.4 - Plot Discharge Data  </h4>

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 2.5 - Identify the Top 3 Discharge Intervals for each Site  </h4>

# %% [markdown]
# <h3 style="font-size:35px;font-family:Helvetica,sans-serif;font-weight:bold">
# 3.0 - Water Quality Comparison</h3>
#
# ***

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 3.1 - Combine Water Quality Data from each Site into the WQ Dataframe  </h4>

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 3.2 - Reindex and Merge WQ Dataframe with Q Dataframe  </h4>

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 3.3 - Create a Series that Contains each Site's Concentration of Acetochlor on the 3 Peak Discharge Intervals   </h4>

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 3.4 - Use the Series Data to Plot a Chart Comparison   </h4>

# %% [markdown]
# <h4 style="font-size:25px;font-family:Helvetica,sans-serif;font-weight:bold;color:#939598">
# 3.5 - Normalize the Series Data by each Site's Drainage Area and Replot  </h4>

# %% [markdown]
# <h3 style="font-size:35px;font-family:Helvetica,sans-serif;font-weight:bold">
# 4.0 - Acetochlor Curves</h3>
#
# ***

# %% [markdown]
# This section will use the discharge and water quality data from the 2020 water year to describe a function that relates the data for each site. These functions will then be used to extrapolate the concentration of Acetochlor at daily intervals for the 2020 water year.
#
# Additioanlly, the chlorophyll and water quality data from the 2020 water year will be used to describe a function that relates the data for each site. These functions will then be used to extrapolate the concentration of Acetochlor at 15-minute intervals for the 2020 water year.

# %% [markdown]
# <h3 style="font-size:35px;font-family:Helvetica,sans-serif;font-weight:bold">
# 5.0 - Curve Comparisons</h3>
#
# ***

# %% [markdown]
# This section will create plots that compare the extrapolation curves from section 4 against each other and the observed 20-day data for the 2020 water year.
